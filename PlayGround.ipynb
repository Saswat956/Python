# %% [markdown]
# # This is line one

# %% [markdown]
# ###### This is line2

# %%
a = 2

# %%
b = 3

# %%
print(a+b)
# Out:
# 5

# %%
a = 2
b = 10
print(a+b)
print(a+b)
print(a+b)
# print(a+b)
# print(a+b)
# print(a+b)
# print(a+b)
# Out:
# 12
# 12
# 12

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.random.randint(1,200,100)
plt.figure(figsize=(16,4))
plt.plot(a,"--r")
plt.show()
